# %% [markdown]
# # Linear Regression

# %%
import tensorflow as tf

# %% [markdown]
# ## 1.build graph using TF operations

# %%
# x and y data
x_train = [1,2,3]
y_train = [1,2,3]

# W weight and b bias
W = tf.Variable(tf.random_normal([1]),name='weight')
b = tf.Variable(tf.random_normal([1]),name='bias')

# our hypothsis
hypothsis = x_train * W + b

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothsis - y_train))

# GradientDescent to Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %% [markdown]
# ### e.g. reduce_mean
#
# t = [1,2,3,4]
# tf.reduce_mean(t) ==>2.5
#
# # 2&3 run and update graph and get results

# %%
# launch the graph in a session
sess = tf.Session()

# inintializes global variables in the graph
sess.run(tf.global_variables_initializer())

print("step,sess.run(cost),sess.run(W),sess.run(b)")
# fit the line
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step,sess.run(cost),sess.run(W),sess.run(b))
# Out:
# step,sess.run(cost),sess.run(W),sess.run(b)
# 0 23.1642 [-0.80268478] [-0.97695786]
# 20 0.213087 [ 0.88650841] [-0.2252337]
# 40 0.00471494 [ 1.04461884] [-0.14744174]
# 60 0.00257025 [ 1.05706918] [-0.13411307]
# 80 0.00231882 [ 1.0557723] [-0.12720084]
# 100 0.00210584 [ 1.0532831] [-0.1211648]
# 120 0.00191256 [ 1.0507915] [-0.11546496]
# 140 0.00173702 [ 1.04840577] [-0.11003795]
# 160 0.00157758 [ 1.04613101] [-0.10486653]
# 180 0.00143279 [ 1.04396296] [-0.09993821]
# 200 0.00130129 [ 1.04189706] [-0.09524153]
# 220 0.00118184 [ 1.03992772] [-0.09076548]
# 240 0.00107337 [ 1.03805137] [-0.08649977]
# 260 0.000974853 [ 1.03626311] [-0.08243459]
# 280 0.000885376 [ 1.03455889] [-0.07856049]
# 300 0.00080411 [ 1.03293467] [-0.0748684]
# 320 0.000730305 [ 1.03138685] [-0.07134981]
# 340 0.000663275 [ 1.02991176] [-0.06799666]
# 360 0.000602398 [ 1.02850604] [-0.06480101]
# 380 0.000547108 [ 1.02716649] [-0.06175561]
# 400 0.00049689 [ 1.02588964] [-0.05885331]
# 420 0.00045128 [ 1.02467287] [-0.05608737]
# 440 0.000409864 [ 1.02351344] [-0.05345149]
# 460 0.000372245 [ 1.02240849] [-0.05093952]
# 480 0.000338081 [ 1.02135527] [-0.0485456]
# 500 0.000307051 [ 1.02035189] [-0.04626417]
# 520 0.000278868 [ 1.01939499] [-0.04408987]
# 540 0.000253271 [ 1.01848364] [-0.04201776]
# 560 0.000230024 [ 1.01761496] [-0.04004303]
# 580 0.000208914 [ 1.01678717] [-0.03816113]
# 600 0.000189735 [ 1.01599824] [-0.03636768]
# 620 0.000172323 [ 1.01524639] [-0.03465853]
# 640 0.000156505 [ 1.01452982] [-0.03302971]
# 660 0.000142142 [ 1.01384699] [-0.03147747]
# 680 0.000129094 [ 1.01319611] [-0.02999809]
# 700 0.000117244 [ 1.01257598] [-0.02858824]
# 720 0.000106484 [ 1.01198494] [-0.02724465]
# 740 9.67109e-05 [ 1.0114218] [-0.02596428]
# 760 8.78345e-05 [ 1.010885] [-0.02474412]
# 780 7.97721e-05 [ 1.01037347] [-0.02358128]
# 800 7.24511e-05 [ 1.00988591] [-0.02247304]
# 820 6.58011e-05 [ 1.00942135] [-0.02141688]
# 840 5.97617e-05 [ 1.00897861] [-0.02041035]
# 860 5.42762e-05 [ 1.0085566] [-0.01945116]
# 880 4.92953e-05 [ 1.00815451] [-0.01853704]
# 900 4.47702e-05 [ 1.00777125] [-0.01766587]
# 920 4.06608e-05 [ 1.007406] [-0.01683564]
